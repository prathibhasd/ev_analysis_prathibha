# %% [markdown]
# # Importing Necessary Libraries
# NumPy is a Python library used for working with arrays. It also has functions for working in domain of linear algebra, fourier transform, and matrices.
# Pandas is a library written for the Python programming language for data manipulation and analysis
# Matplotlib is one of the most popular Python packages used for data visualization. It is a cross-platform library for making 2D plots from data in arrays.
# Seaborn is an open-source Python library built on top of matplotlib. It is used for data visualization and exploratory data analysis.
# Warnings are provided to warn the developer of situations that aren’t necessarily exceptions

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.cluster import KMeans

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("Market segmentation newest.csv")

# %%
df.head()
# Out:
#           States  2022estimates  2wheeler  3wheeler     4W   Bus   Total  \
# 0   UttarPradesh      233200000     27000    113400      0  1860  142260
# 1    Maharashtra      125400000    105300      2700  10800  1022  119822
# 2          Bihar      124900000      5400     39550      0     0   44950
# 3     WestBengal       98600000      1958         0      0     0    1958
# 4  MadhyaPradesh       85500000      2327       945    608    58    3938
#
#    EVSTATIONS  PCINCOME  TOTALEVVEHICLES  ...  Avg.annualhightempcelsius  \
# 0         207     65431           337180  ...                       33.0
# 1         317    202130           116646  ...                       34.0
# 2          37     46292            83335  ...                       31.0
# 3         141    121463            48767  ...                       32.0
# 4         235     98418             5100  ...                       32.0
#
#    Avg.annuallowtempcelsius  perkWhofbatterycapacityfor2w  MaxSubsidyfor2w  \
# ...

# %% [markdown]
# # Analysing the Dataset

# %%
df.describe()
# Out:
#        2022estimates       2wheeler       3wheeler            4W          Bus  \
# count   3.600000e+01      36.000000      36.000000     36.000000    36.000000
# mean    3.817714e+07   12316.666667    6800.138889   1009.750000   113.472222
# std     4.954886e+07   25231.999962   20585.224127   2209.438692   370.275533
# min     6.800000e+04       0.000000       0.000000      0.000000     0.000000
# 25%     1.597750e+06      17.000000      66.250000      3.750000     0.000000
# 50%     2.540000e+07    1227.000000     704.500000    121.500000     0.000000
# 75%     5.655000e+07    3375.000000    1350.000000    616.750000    10.500000
# max     2.332000e+08  105300.000000  113400.000000  10800.000000  1860.000000
#
#                Total  EVSTATIONS       PCINCOME  TOTALEVVEHICLES  \
# count      36.000000   36.000000      36.000000        36.000000
# mean    20239.972222   80.416667  172507.500000     37957.944444
# std     36490.205964  102.290168   96572.294466     65144.488394
# ...

# %% [markdown]
# # Checking for Null values in the dataset

# %%
df.isna().sum()
# Out:
# States                          0
# 2022estimates                   0
# 2wheeler                        0
# 3wheeler                        0
# 4W                              0
# Bus                             0
# Total                           0
# EVSTATIONS                      0
# PCINCOME                        0
# TOTALEVVEHICLES                 0
# PetrolPrices                    0
# DieselPrices                    0
# Avg.annualhightempcelsius       0
# Avg.annuallowtempcelsius        0
# perkWhofbatterycapacityfor2w    0
# MaxSubsidyfor2w                 0
# Roadtaxexemption2w              0
# perkWhofbatterycapacityfor4w    0
# MaxSubsidyfor4w                 0
# Roadtaxexemption4w              0
# Avgunitrate                     0
# AirQualityIndex                 0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 22 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   States                        36 non-null     object
#  1   2022estimates                 36 non-null     int64
#  2   2wheeler                      36 non-null     int64
#  3   3wheeler                      36 non-null     int64
#  4   4W                            36 non-null     int64
#  5   Bus                           36 non-null     int64
#  6   Total                         36 non-null     int64
#  7   EVSTATIONS                    36 non-null     int64
#  8   PCINCOME                      36 non-null     int64
#  9   TOTALEVVEHICLES               36 non-null     int64
#  10  PetrolPrices                  36 non-null     float64
#  11  DieselPrices                  36 non-null     float64
# ...

# %% [markdown]
# # Extracting Segments

# %%
df['perkWhofbatterycapacityfor2w'] = df['perkWhofbatterycapacityfor2w'].str.replace(r'\D', '')
df
# Out:
#                            States  2022estimates  2wheeler  3wheeler     4W  \
# 0                    UttarPradesh      233200000     27000    113400      0
# 1                     Maharashtra      125400000    105300      2700  10800
# 2                           Bihar      124900000      5400     39550      0
# 3                      WestBengal       98600000      1958         0      0
# 4                   MadhyaPradesh       85500000      2327       945    608
# 5                       TamilNadu       76600000     62100      5670   5864
# 6                       Rajasthan       80000000      2009       572    335
# 7                       Karnataka       67200000     81000      7830   5400
# 8                         Gujarat       70000000     54000      1350   3353
# 9                   AndhraPradesh       53000000      2171         0    643
# 10                         Odisha       46000000     24300      1350    837
# ...

# %%
df['perkWhofbatterycapacityfor4w'] = df['perkWhofbatterycapacityfor4w'].str.replace(r'\D', '')
df
# Out:
#                            States  2022estimates  2wheeler  3wheeler     4W  \
# 0                    UttarPradesh      233200000     27000    113400      0
# 1                     Maharashtra      125400000    105300      2700  10800
# 2                           Bihar      124900000      5400     39550      0
# 3                      WestBengal       98600000      1958         0      0
# 4                   MadhyaPradesh       85500000      2327       945    608
# 5                       TamilNadu       76600000     62100      5670   5864
# 6                       Rajasthan       80000000      2009       572    335
# 7                       Karnataka       67200000     81000      7830   5400
# 8                         Gujarat       70000000     54000      1350   3353
# 9                   AndhraPradesh       53000000      2171         0    643
# 10                         Odisha       46000000     24300      1350    837
# ...

# %%
df['MaxSubsidyfor4w'] = df['MaxSubsidyfor4w'].str.replace(r'\D', '')
df
# Out:
#                            States  2022estimates  2wheeler  3wheeler     4W  \
# 0                    UttarPradesh      233200000     27000    113400      0
# 1                     Maharashtra      125400000    105300      2700  10800
# 2                           Bihar      124900000      5400     39550      0
# 3                      WestBengal       98600000      1958         0      0
# 4                   MadhyaPradesh       85500000      2327       945    608
# 5                       TamilNadu       76600000     62100      5670   5864
# 6                       Rajasthan       80000000      2009       572    335
# 7                       Karnataka       67200000     81000      7830   5400
# 8                         Gujarat       70000000     54000      1350   3353
# 9                   AndhraPradesh       53000000      2171         0    643
# 10                         Odisha       46000000     24300      1350    837
# ...

# %%
df['Roadtaxexemption2w'] = df['Roadtaxexemption2w'].str.replace(r'\D', '')
df
# Out:
#                            States  2022estimates  2wheeler  3wheeler     4W  \
# 0                    UttarPradesh      233200000     27000    113400      0
# 1                     Maharashtra      125400000    105300      2700  10800
# 2                           Bihar      124900000      5400     39550      0
# 3                      WestBengal       98600000      1958         0      0
# 4                   MadhyaPradesh       85500000      2327       945    608
# 5                       TamilNadu       76600000     62100      5670   5864
# 6                       Rajasthan       80000000      2009       572    335
# 7                       Karnataka       67200000     81000      7830   5400
# 8                         Gujarat       70000000     54000      1350   3353
# 9                   AndhraPradesh       53000000      2171         0    643
# 10                         Odisha       46000000     24300      1350    837
# ...

# %%
df['Roadtaxexemption4w'] = df['Roadtaxexemption4w'].str.replace(r'\D', '')
df
# Out:
#                            States  2022estimates  2wheeler  3wheeler     4W  \
# 0                    UttarPradesh      233200000     27000    113400      0
# 1                     Maharashtra      125400000    105300      2700  10800
# 2                           Bihar      124900000      5400     39550      0
# 3                      WestBengal       98600000      1958         0      0
# 4                   MadhyaPradesh       85500000      2327       945    608
# 5                       TamilNadu       76600000     62100      5670   5864
# 6                       Rajasthan       80000000      2009       572    335
# 7                       Karnataka       67200000     81000      7830   5400
# 8                         Gujarat       70000000     54000      1350   3353
# 9                   AndhraPradesh       53000000      2171         0    643
# 10                         Odisha       46000000     24300      1350    837
# ...

# %% [markdown]
# # EDA(Exploratory Data Analysis)

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
df.drop(columns=['PetrolPrices'],inplace=True)

# %%
df
# Out:
#                            States  2022estimates  2wheeler  3wheeler     4W  \
# 0                    UttarPradesh      233200000     27000    113400      0
# 1                     Maharashtra      125400000    105300      2700  10800
# 2                           Bihar      124900000      5400     39550      0
# 3                      WestBengal       98600000      1958         0      0
# 4                   MadhyaPradesh       85500000      2327       945    608
# 5                       TamilNadu       76600000     62100      5670   5864
# 6                       Rajasthan       80000000      2009       572    335
# 7                       Karnataka       67200000     81000      7830   5400
# 8                         Gujarat       70000000     54000      1350   3353
# 9                   AndhraPradesh       53000000      2171         0    643
# 10                         Odisha       46000000     24300      1350    837
# ...

# %%
df.columns.unique()
# Out:
# Index(['States', '2022estimates', '2wheeler', '3wheeler', '4W', 'Bus', 'Total',
#        'EVSTATIONS', 'PCINCOME', 'TOTALEVVEHICLES', 'DieselPrices',
#        'Avg.annualhightempcelsius', 'Avg.annuallowtempcelsius',
#        'perkWhofbatterycapacityfor2w', 'MaxSubsidyfor2w', 'Roadtaxexemption2w',
#        'perkWhofbatterycapacityfor4w', 'MaxSubsidyfor4w', 'Roadtaxexemption4w',
#        'Avgunitrate', 'AirQualityIndex'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 21 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   States                        36 non-null     object
#  1   2022estimates                 36 non-null     int64
#  2   2wheeler                      36 non-null     int64
#  3   3wheeler                      36 non-null     int64
#  4   4W                            36 non-null     int64
#  5   Bus                           36 non-null     int64
#  6   Total                         36 non-null     int64
#  7   EVSTATIONS                    36 non-null     int64
#  8   PCINCOME                      36 non-null     int64
#  9   TOTALEVVEHICLES               36 non-null     int64
#  10  DieselPrices                  36 non-null     float64
#  11  Avg.annualhightempcelsius     36 non-null     float64
# ...

# %%
category = []
for i in df.columns:
  if df[i].dtype=='O':
    category.append(i)


for i in category:
  print('Distribution of',i)
  print(df[i].value_counts())
  print('-'*60)
# Out:
# Distribution of States
# UttarPradesh                     1
# Maharashtra                      1
# Uttarakhand                      1
# HimachalPradesh                  1
# Tripura                          1
# Meghalaya                        1
# Manipur                          1
# Nagaland                         1
# Goa                              1
# ArunachalPradesh                 1
# Puducherry                       1
# Mizoram                          1
# Chandigarh                       1
# Sikkim                           1
# Dadra&NagarHaveliandDaman&Diu    1
# Andaman&Nicobar                  1
# Ladakh                           1
# Jammu&Kashmir                    1
# Delhi                            1
# Haryana                          1
# Gujarat                          1
# Bihar                            1
# WestBengal                       1
# MadhyaPradesh                    1
# TamilNadu                        1
# Rajasthan                        1
# ...

# %%
df.columns.unique()
# Out:
# Index(['States', '2022estimates', '2wheeler', '3wheeler', '4W', 'Bus', 'Total',
#        'EVSTATIONS', 'PCINCOME', 'TOTALEVVEHICLES', 'DieselPrices',
#        'Avg.annualhightempcelsius', 'Avg.annuallowtempcelsius',
#        'perkWhofbatterycapacityfor2w', 'MaxSubsidyfor2w', 'Roadtaxexemption2w',
#        'perkWhofbatterycapacityfor4w', 'MaxSubsidyfor4w', 'Roadtaxexemption4w',
#        'Avgunitrate', 'AirQualityIndex'],
#       dtype='object')

# %%
df['2wheeler'].value_counts()
# Out:
# 0         8
# 270       2
# 27000     1
# 105300    1
# 19        1
# 405       1
# 200       1
# 189       1
# 621       1
# 559       1
# 1644      1
# 29700     1
# 810       1
# 1647      1
# 2700      1
# 2279      1
# 32400     1
# 2111      1
# 24300     1
# 2171      1
# 54000     1
# 81000     1
# 2009      1
# 62100     1
# 2327      1
# 1958      1
# 5400      1
# 11        1
# Name: 2wheeler, dtype: int64

# %%
df.plot(x='States',y='Total',kind='bar',stacked=True,title="States v/s Total")
df.plot(x='States',y='Bus',kind='bar',stacked=False,title='States v/s Bus')
df.plot(x='States',y='3wheeler',kind='bar',stacked=False,title='States v/s 3w')
df.plot(x='States',y='4W', kind='bar',
        stacked=True,
        title='States v/s 4W')

df.plot(x='States',y='2wheeler',
        kind='bar',
        stacked=False,
        title='States v/s 2 wheeler')
df.plot(x="States",y="EVSTATIONS",kind='bar',stacked=True,title='States v/s EVS')
# Out:
# <AxesSubplot:title={'center':'States v/s EVS'}, xlabel='States'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 21 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   States                        36 non-null     object
#  1   2022estimates                 36 non-null     int64
#  2   2wheeler                      36 non-null     int64
#  3   3wheeler                      36 non-null     int64
#  4   4W                            36 non-null     int64
#  5   Bus                           36 non-null     int64
#  6   Total                         36 non-null     int64
#  7   EVSTATIONS                    36 non-null     int64
#  8   PCINCOME                      36 non-null     int64
#  9   TOTALEVVEHICLES               36 non-null     int64
#  10  DieselPrices                  36 non-null     float64
#  11  Avg.annualhightempcelsius     36 non-null     float64
# ...

# %%
df['2022estimates'] = df['2022estimates'].astype(int)

# %%
df1=df[df['Total']>0]

# %%
df1
# Out:
#                            States  2022estimates  2wheeler  3wheeler     4W  \
# 0                    UttarPradesh      233200000     27000    113400      0
# 1                     Maharashtra      125400000    105300      2700  10800
# 2                           Bihar      124900000      5400     39550      0
# 3                      WestBengal       98600000      1958         0      0
# 4                   MadhyaPradesh       85500000      2327       945    608
# 5                       TamilNadu       76600000     62100      5670   5864
# 6                       Rajasthan       80000000      2009       572    335
# 7                       Karnataka       67200000     81000      7830   5400
# 8                         Gujarat       70000000     54000      1350   3353
# 9                   AndhraPradesh       53000000      2171         0    643
# 10                         Odisha       46000000     24300      1350    837
# ...

# %%
df1.reset_index()
# Out:
#     index                         States  2022estimates  2wheeler  3wheeler  \
# 0       0                   UttarPradesh      233200000     27000    113400
# 1       1                    Maharashtra      125400000    105300      2700
# 2       2                          Bihar      124900000      5400     39550
# 3       3                     WestBengal       98600000      1958         0
# 4       4                  MadhyaPradesh       85500000      2327       945
# 5       5                      TamilNadu       76600000     62100      5670
# 6       6                      Rajasthan       80000000      2009       572
# 7       7                      Karnataka       67200000     81000      7830
# 8       8                        Gujarat       70000000     54000      1350
# 9       9                  AndhraPradesh       53000000      2171         0
# 10     10                         Odisha       46000000     24300      1350
# ...

# %%
df1.columns.unique()
# Out:
# Index(['States', '2022estimates', '2wheeler', '3wheeler', '4W', 'Bus', 'Total',
#        'EVSTATIONS', 'PCINCOME', 'TOTALEVVEHICLES', 'DieselPrices',
#        'Avg.annualhightempcelsius', 'Avg.annuallowtempcelsius',
#        'perkWhofbatterycapacityfor2w', 'MaxSubsidyfor2w', 'Roadtaxexemption2w',
#        'perkWhofbatterycapacityfor4w', 'MaxSubsidyfor4w', 'Roadtaxexemption4w',
#        'Avgunitrate', 'AirQualityIndex'],
#       dtype='object')

# %%
df2=df1[['2022estimates', '3wheeler', '4W', 'Bus', 'Total',
       'EVSTATIONS', 'PCINCOME', 'TOTALEVVEHICLES', 'DieselPrices',
       'Avg.annualhightempcelsius', 'Avg.annuallowtempcelsius',
       'perkWhofbatterycapacityfor2w', 'MaxSubsidyfor2w', 'Roadtaxexemption2w',
       'perkWhofbatterycapacityfor4w', 'MaxSubsidyfor4w', 'Roadtaxexemption4w',
       'Avgunitrate', 'AirQualityIndex']]

# %%
df2.head()
# Out:
#    2022estimates  3wheeler     4W   Bus   Total  EVSTATIONS  PCINCOME  \
# 0      233200000    113400      0  1860  142260         207     65431
# 1      125400000      2700  10800  1022  119822         317    202130
# 2      124900000     39550      0     0   44950          37     46292
# 3       98600000         0      0     0    1958         141    121463
# 4       85500000       945    608    58    3938         235     98418
#
#    TOTALEVVEHICLES  DieselPrices  Avg.annualhightempcelsius  \
# 0           337180         89.71                       33.0
# 1           116646         95.59                       34.0
# 2            83335         94.04                       31.0
# 3            48767         92.76                       32.0
# 4             5100         93.93                       32.0
#
#    Avg.annuallowtempcelsius perkWhofbatterycapacityfor2w  MaxSubsidyfor2w  \
# 0                      18.0                        20000             1000
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33 entries, 0 to 35
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   2022estimates                 33 non-null     int32
#  1   3wheeler                      33 non-null     int64
#  2   4W                            33 non-null     int64
#  3   Bus                           33 non-null     int64
#  4   Total                         33 non-null     int64
#  5   EVSTATIONS                    33 non-null     int64
#  6   PCINCOME                      33 non-null     int64
#  7   TOTALEVVEHICLES               33 non-null     int64
#  8   DieselPrices                  33 non-null     float64
#  9   Avg.annualhightempcelsius     33 non-null     float64
#  10  Avg.annuallowtempcelsius      33 non-null     float64
#  11  perkWhofbatterycapacityfor2w  33 non-null     object
# ...

# %%
#df2['PCINCOME'] = df2['PCINCOME'].str.replace(r',', '')
#df2

# %%
df2['perkWhofbatterycapacityfor2w'].unique()
# Out:
# array(['20000', '5000', '10000', '2500'], dtype=object)

# %%
df2['PCINCOME'] = df2['PCINCOME'].astype(int)

# %%
df2['perkWhofbatterycapacityfor2w']=df2['perkWhofbatterycapacityfor2w'].astype(int)

# %%
df2['Roadtaxexemption2w'].unique()
# Out:
# array(['100', '99', '0', '50'], dtype=object)

# %%
df2['Roadtaxexemption2w']=df2['Roadtaxexemption2w'].astype(int)

# %%
df2['perkWhofbatterycapacityfor4w'].unique()
# Out:
# array(['20000', '5000', '10000'], dtype=object)

# %%
df2['perkWhofbatterycapacityfor4w']=df2['perkWhofbatterycapacityfor4w'].astype(int)

# %%
df2['MaxSubsidyfor4w']=df2['MaxSubsidyfor4w'].astype(int)

# %%
df2['Roadtaxexemption4w']=df2['Roadtaxexemption4w'].astype(int)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33 entries, 0 to 35
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   2022estimates                 33 non-null     int32
#  1   3wheeler                      33 non-null     int64
#  2   4W                            33 non-null     int64
#  3   Bus                           33 non-null     int64
#  4   Total                         33 non-null     int64
#  5   EVSTATIONS                    33 non-null     int64
#  6   PCINCOME                      33 non-null     int32
#  7   TOTALEVVEHICLES               33 non-null     int64
#  8   DieselPrices                  33 non-null     float64
#  9   Avg.annualhightempcelsius     33 non-null     float64
#  10  Avg.annuallowtempcelsius      33 non-null     float64
#  11  perkWhofbatterycapacityfor2w  33 non-null     int32
#  12  MaxSubsidyfor2w               33 non-null     int64
# ...

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df2.corr(), annot=True)
plt.show()

# %%
df2.drop(columns=['perkWhofbatterycapacityfor4w'],inplace=True)

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df2.corr(), annot=True)
plt.show()

# %%
df2.drop(columns=['perkWhofbatterycapacityfor2w'],inplace=True)

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df2.corr(), annot=True)
plt.show()

# %%
df2.drop(columns=['TOTALEVVEHICLES'],inplace=True)

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df2.corr(), annot=True)
plt.show()

# %%
wcss = []
for i in range(1,11):
    kmeans_pca = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans_pca.fit(df2)
    wcss.append(kmeans_pca.inertia_)

# %%
plt.plot(wcss)

# %% [markdown]
# # Clustering using KMeans

# %%
kmeans = KMeans(n_clusters=2)
kmeans.fit(df2)
# Out:
# KMeans(n_clusters=2)

# %%
df2['Cluster_Id'] = kmeans.labels_
df2.head()
# Out:
#    2022estimates  3wheeler     4W   Bus   Total  EVSTATIONS  PCINCOME  \
# 0      233200000    113400      0  1860  142260         207     65431
# 1      125400000      2700  10800  1022  119822         317    202130
# 2      124900000     39550      0     0   44950          37     46292
# 3       98600000         0      0     0    1958         141    121463
# 4       85500000       945    608    58    3938         235     98418
#
#    DieselPrices  Avg.annualhightempcelsius  Avg.annuallowtempcelsius  \
# 0         89.71                       33.0                      18.0
# 1         95.59                       34.0                      17.0
# 2         94.04                       31.0                      20.0
# 3         92.76                       32.0                      22.0
# 4         93.93                       32.0                      19.0
#
#    MaxSubsidyfor2w  Roadtaxexemption2w  MaxSubsidyfor4w  Roadtaxexemption4w  \
# ...

# %%
df2.columns.unique()
# Out:
# Index(['2022estimates', '3wheeler', '4W', 'Bus', 'Total', 'EVSTATIONS',
#        'PCINCOME', 'DieselPrices', 'Avg.annualhightempcelsius',
#        'Avg.annuallowtempcelsius', 'MaxSubsidyfor2w', 'Roadtaxexemption2w',
#        'MaxSubsidyfor4w', 'Roadtaxexemption4w', 'Avgunitrate',
#        'AirQualityIndex', 'Cluster_Id'],
#       dtype='object')

# %%
df2["States"]=df1["States"]

# %%
df2.head()
# Out:
#    2022estimates  3wheeler     4W   Bus   Total  EVSTATIONS  PCINCOME  \
# 0      233200000    113400      0  1860  142260         207     65431
# 1      125400000      2700  10800  1022  119822         317    202130
# 2      124900000     39550      0     0   44950          37     46292
# 3       98600000         0      0     0    1958         141    121463
# 4       85500000       945    608    58    3938         235     98418
#
#    DieselPrices  Avg.annualhightempcelsius  Avg.annuallowtempcelsius  \
# 0         89.71                       33.0                      18.0
# 1         95.59                       34.0                      17.0
# 2         94.04                       31.0                      20.0
# 3         92.76                       32.0                      22.0
# 4         93.93                       32.0                      19.0
#
#    MaxSubsidyfor2w  Roadtaxexemption2w  MaxSubsidyfor4w  Roadtaxexemption4w  \
# ...

# %%
len(df2[df2["Cluster_Id"]==1])
# Out:
# 9

# %%
colors = ['#DF2020', '#81DF20', '#2095DF']
df2['c'] = df2.Cluster_Id.map({0:colors[0], 1:colors[1]})

# %%
from matplotlib.lines import Line2D
legend_elements = [Line2D([0], [0], marker='o', color='w', label='Cluster {}'.format(i), 
               markerfacecolor=mcolor, markersize=5) for i, mcolor in enumerate(colors)]
plt.legend(handles=legend_elements, loc='upper right')

plt.scatter(df2.States, df2.Total, c=df2.c, alpha = 0.6, s=120)
#plt.plot(x, y)
#x=df2["States"]
#y=df2['TOTALEVVEHICLES']
plt.xticks(rotation = 90) # Rotates X-Axis Ticks by 90-degrees
plt.show()

# %%
df2.rename(columns = {'4W':'FourW'}, inplace = True)

# %%
df2.rename(columns = {'3wheeler':'ThreeW'}, inplace = True)

# %%
df2['c'].unique()
# Out:
# array(['#81DF20', '#DF2020'], dtype=object)

# %%
df2.head()
# Out:
#    2022estimates  ThreeW  FourW   Bus   Total  EVSTATIONS  PCINCOME  \
# 0      233200000  113400      0  1860  142260         207     65431
# 1      125400000    2700  10800  1022  119822         317    202130
# 2      124900000   39550      0     0   44950          37     46292
# 3       98600000       0      0     0    1958         141    121463
# 4       85500000     945    608    58    3938         235     98418
#
#    DieselPrices  Avg.annualhightempcelsius  Avg.annuallowtempcelsius  \
# 0         89.71                       33.0                      18.0
# 1         95.59                       34.0                      17.0
# 2         94.04                       31.0                      20.0
# 3         92.76                       32.0                      22.0
# 4         93.93                       32.0                      19.0
#
#    MaxSubsidyfor2w  Roadtaxexemption2w  MaxSubsidyfor4w  Roadtaxexemption4w  \
# ...

# %%
legend_elements = [Line2D([0], [0], marker='o', color='w', label='Cluster {}'.format(i), 
               markerfacecolor=mcolor, markersize=5) for i, mcolor in enumerate(colors)]
plt.legend(handles=legend_elements, loc='upper right')

plt.scatter(df2.States, df2.ThreeW, c=df2.c, alpha = 0.6, s=120)
plt.xticks(rotation = 90)
plt.show()

# %%
legend_elements = [Line2D([0], [0], marker='o', color='w', label='Cluster {}'.format(i), 
               markerfacecolor=mcolor, markersize=5) for i, mcolor in enumerate(colors)]
plt.legend(handles=legend_elements, loc='upper right')

plt.scatter(df2.States, df2.FourW, c=df2.c, alpha = 0.6, s=120)
#plt.plot(x, y)
#x=df2["States"]
#y=df2['TOTALEVVEHICLES']
plt.xticks(rotation = 90) # Rotates X-Axis Ticks by 90-degrees
plt.show()

# %%
from matplotlib.lines import Line2D
legend_elements = [Line2D([0], [0], marker='o', color='w', label='Cluster {}'.format(i), 
               markerfacecolor=mcolor, markersize=5) for i, mcolor in enumerate(colors)]
plt.legend(handles=legend_elements, loc='upper right')

plt.scatter(df2.States, df2.Bus ,c=df2.c, alpha = 0.6, s=120)
#plt.plot(x, y)
#x=df2["States"]
#y=df2['TOTALEVVEHICLES']
plt.xticks(rotation = 90) # Rotates X-Axis Ticks by 90-degrees
plt.show()

# %%
from matplotlib.lines import Line2D
legend_elements = [Line2D([0], [0], marker='o', color='w', label='Cluster {}'.format(i), 
               markerfacecolor=mcolor, markersize=5) for i, mcolor in enumerate(colors)]
plt.legend(handles=legend_elements, loc='upper right')

plt.scatter(df2.States, df2.Total ,c=df2.c, alpha = 0.6, s=120)
#plt.plot(x, y)
#x=df2["States"]
#y=df2['TOTALEVVEHICLES']
plt.xticks(rotation = 90) # Rotates X-Axis Ticks by 90-degrees
plt.show()

# %%
df4=df2[['Total','EVSTATIONS', 'PCINCOME', 'DieselPrices',
       'Avg.annualhightempcelsius', 'Avg.annuallowtempcelsius', 'MaxSubsidyfor2w', 'Roadtaxexemption2w', 'Roadtaxexemption4w',
       'Avgunitrate', 'AirQualityIndex']]

# %%
df4["2wheeler"]=df1['2wheeler']

# %%
df4.head()
# Out:
#     Total  EVSTATIONS  PCINCOME  DieselPrices  Avg.annualhightempcelsius  \
# 0  142260         207     65431         89.71                       33.0
# 1  119822         317    202130         95.59                       34.0
# 2   44950          37     46292         94.04                       31.0
# 3    1958         141    121463         92.76                       32.0
# 4    3938         235     98418         93.93                       32.0
#
#    Avg.annuallowtempcelsius  MaxSubsidyfor2w  Roadtaxexemption2w  \
# 0                      18.0             1000                 100
# 1                      17.0            25000                 100
# 2                      20.0            20000                 100
# 3                      22.0            20000                 100
# 4                      19.0             1000                  99
#
#    Roadtaxexemption4w  Avgunitrate  AirQualityIndex  2wheeler
# 0                  75         6.50              105     27000
# ...

# %%
wcss = []
for i in range(1,11):
    kmeans_pca = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans_pca.fit(df4)
    wcss.append(kmeans_pca.inertia_)

# %%
plt.plot(wcss)

# %%
kmeans = KMeans(n_clusters=2)
kmeans.fit(df4)
# Out:
# KMeans(n_clusters=2)

# %%
df4['Cluster_Id'] = kmeans.labels_
df4.head()
# Out:
#     Total  EVSTATIONS  PCINCOME  DieselPrices  Avg.annualhightempcelsius  \
# 0  142260         207     65431         89.71                       33.0
# 1  119822         317    202130         95.59                       34.0
# 2   44950          37     46292         94.04                       31.0
# 3    1958         141    121463         92.76                       32.0
# 4    3938         235     98418         93.93                       32.0
#
#    Avg.annuallowtempcelsius  MaxSubsidyfor2w  Roadtaxexemption2w  \
# 0                      18.0             1000                 100
# 1                      17.0            25000                 100
# 2                      20.0            20000                 100
# 3                      22.0            20000                 100
# 4                      19.0             1000                  99
#
#    Roadtaxexemption4w  Avgunitrate  AirQualityIndex  2wheeler  Cluster_Id
# ...

# %%
df4["States"]=df2["States"]

# %%
df4.head()
# Out:
#     Total  EVSTATIONS  PCINCOME  DieselPrices  Avg.annualhightempcelsius  \
# 0  142260         207     65431         89.71                       33.0
# 1  119822         317    202130         95.59                       34.0
# 2   44950          37     46292         94.04                       31.0
# 3    1958         141    121463         92.76                       32.0
# 4    3938         235     98418         93.93                       32.0
#
#    Avg.annuallowtempcelsius  MaxSubsidyfor2w  Roadtaxexemption2w  \
# 0                      18.0             1000                 100
# 1                      17.0            25000                 100
# 2                      20.0            20000                 100
# 3                      22.0            20000                 100
# 4                      19.0             1000                  99
#
#    Roadtaxexemption4w  Avgunitrate  AirQualityIndex  2wheeler  Cluster_Id  \
# ...

# %%
df4.rename(columns = {'2wheeler':'TwoW'}, inplace = True)

# %%
from matplotlib.lines import Line2D
legend_elements = [Line2D([0], [0], marker='o', color='w', label='Cluster {}'.format(i), 
               markerfacecolor=mcolor, markersize=5) for i, mcolor in enumerate(colors)]
plt.legend(handles=legend_elements, loc='upper right')

plt.scatter(df4.States, df4.TwoW ,c=df2.c, alpha = 0.6, s=120)

plt.xticks(rotation = 90) # Rotates X-Axis Ticks by 90-degrees
plt.show()

# %%
from matplotlib.lines import Line2D
legend_elements = [Line2D([0], [0], marker='o', color='w', label='Cluster {}'.format(i), 
               markerfacecolor=mcolor, markersize=5) for i, mcolor in enumerate(colors)]
plt.legend(handles=legend_elements, loc='upper right')

plt.scatter(df4.States, df4.MaxSubsidyfor2w ,c=df2.c, alpha = 0.6, s=120)
#plt.plot(x, y)
#x=df2["States"]
#y=df2['TOTALEVVEHICLES']
plt.xticks(rotation = 90) # Rotates X-Axis Ticks by 90-degrees
plt.show()

# %%
from matplotlib.lines import Line2D
legend_elements = [Line2D([0], [0], marker='o', color='w', label='Cluster {}'.format(i), 
               markerfacecolor=mcolor, markersize=5) for i, mcolor in enumerate(colors)]
plt.legend(handles=legend_elements, loc='upper right')

plt.scatter(df4.States, df4.AirQualityIndex ,c=df2.c, alpha = 0.6, s=120)
#plt.plot(x, y)
#x=df2["States"]
#y=df2['TOTALEVVEHICLES']
plt.xticks(rotation = 90) # Rotates X-Axis Ticks by 90-degrees
plt.show()

# %%
from matplotlib.lines import Line2D
legend_elements = [Line2D([0], [0], marker='o', color='w', label='Cluster {}'.format(i), 
               markerfacecolor=mcolor, markersize=5) for i, mcolor in enumerate(colors)]
plt.legend(handles=legend_elements, loc='upper right')

plt.scatter(df2.States, df2.EVSTATIONS ,c=df2.c, alpha = 0.6, s=120)
#plt.plot(x, y)
#x=df2["States"]
#y=df2['TOTALEVVEHICLES']
plt.xticks(rotation = 90) # Rotates X-Axis Ticks by 90-degrees
plt.show()

# %%
from matplotlib.lines import Line2D
legend_elements = [Line2D([0], [0], marker='o', color='w', label='Cluster {}'.format(i), 
               markerfacecolor=mcolor, markersize=5) for i, mcolor in enumerate(colors)]
plt.legend(handles=legend_elements, loc='upper right')

plt.scatter(df2.States, df2.PCINCOME ,c=df2.c, alpha = 0.6, s=120)
#plt.plot(x, y)
#x=df2["States"]
#y=df2['TOTALEVVEHICLES']
plt.xticks(rotation = 90) # Rotates X-Axis Ticks by 90-degrees
plt.show()

# %%
from matplotlib.lines import Line2D
legend_elements = [Line2D([0], [0], marker='o', color='w', label='Cluster {}'.format(i), 
               markerfacecolor=mcolor, markersize=5) for i, mcolor in enumerate(colors)]
plt.legend(handles=legend_elements, loc='upper right')

plt.scatter(df2.States, df2.DieselPrices ,c=df2.c, alpha = 0.6, s=120)
#plt.plot(x, y)
#x=df2["States"]
#y=df2['TOTALEVVEHICLES']
plt.xticks(rotation = 90) # Rotates X-Axis Ticks by 90-degrees
plt.show()

# %% [markdown]
# # Visualization

# %%
df2['P3'] = (df2['ThreeW'] / 
                 df2['2022estimates'] * 100)

# %%
df2.head()
# Out:
#    2022estimates  ThreeW  FourW   Bus   Total  EVSTATIONS  PCINCOME  \
# 0      233200000  113400      0  1860  142260         207     65431
# 1      125400000    2700  10800  1022  119822         317    202130
# 2      124900000   39550      0     0   44950          37     46292
# 3       98600000       0      0     0    1958         141    121463
# 4       85500000     945    608    58    3938         235     98418
#
#    DieselPrices  Avg.annualhightempcelsius  Avg.annuallowtempcelsius  \
# 0         89.71                       33.0                      18.0
# 1         95.59                       34.0                      17.0
# 2         94.04                       31.0                      20.0
# 3         92.76                       32.0                      22.0
# 4         93.93                       32.0                      19.0
#
#    MaxSubsidyfor2w  Roadtaxexemption2w  MaxSubsidyfor4w  Roadtaxexemption4w  \
# ...

# %%
df2['P4'] = (df2['FourW'] / 
                 df2['2022estimates'] * 100)

# %%
df2['BusP'] = (df2['Bus'] / 
                 df2['2022estimates'] * 100)

# %%
df2.head()
# Out:
#    2022estimates  ThreeW  FourW   Bus   Total  EVSTATIONS  PCINCOME  \
# 0      233200000  113400      0  1860  142260         207     65431
# 1      125400000    2700  10800  1022  119822         317    202130
# 2      124900000   39550      0     0   44950          37     46292
# 3       98600000       0      0     0    1958         141    121463
# 4       85500000     945    608    58    3938         235     98418
#
#    DieselPrices  Avg.annualhightempcelsius  Avg.annuallowtempcelsius  ...  \
# 0         89.71                       33.0                      18.0  ...
# 1         95.59                       34.0                      17.0  ...
# 2         94.04                       31.0                      20.0  ...
# 3         92.76                       32.0                      22.0  ...
# 4         93.93                       32.0                      19.0  ...
#
#    MaxSubsidyfor4w  Roadtaxexemption4w  Avgunitrate  AirQualityIndex  \
# ...

# %%
df2['TotalP'] = (df2['Total'] / 
                 df2['2022estimates'] * 100)

# %%
df2.head()
# Out:
#    2022estimates  ThreeW  FourW   Bus   Total  EVSTATIONS  PCINCOME  \
# 0      233200000  113400      0  1860  142260         207     65431
# 1      125400000    2700  10800  1022  119822         317    202130
# 2      124900000   39550      0     0   44950          37     46292
# 3       98600000       0      0     0    1958         141    121463
# 4       85500000     945    608    58    3938         235     98418
#
#    DieselPrices  Avg.annualhightempcelsius  Avg.annuallowtempcelsius  ...  \
# 0         89.71                       33.0                      18.0  ...
# 1         95.59                       34.0                      17.0  ...
# 2         94.04                       31.0                      20.0  ...
# 3         92.76                       32.0                      22.0  ...
# 4         93.93                       32.0                      19.0  ...
#
#    Roadtaxexemption4w  Avgunitrate  AirQualityIndex  Cluster_Id  \
# ...

# %%
df2['EVSTATIONSP'] = (df2['EVSTATIONS'] / 
                df2['Total'] * 100)

# %%
df2.head()
# Out:
#    2022estimates  ThreeW  FourW   Bus   Total  EVSTATIONS  PCINCOME  \
# 0      233200000  113400      0  1860  142260         207     65431
# 1      125400000    2700  10800  1022  119822         317    202130
# 2      124900000   39550      0     0   44950          37     46292
# 3       98600000       0      0     0    1958         141    121463
# 4       85500000     945    608    58    3938         235     98418
#
#    DieselPrices  Avg.annualhightempcelsius  Avg.annuallowtempcelsius  ...  \
# 0         89.71                       33.0                      18.0  ...
# 1         95.59                       34.0                      17.0  ...
# 2         94.04                       31.0                      20.0  ...
# 3         92.76                       32.0                      22.0  ...
# 4         93.93                       32.0                      19.0  ...
#
#    Avgunitrate  AirQualityIndex  Cluster_Id         States        c        P3  \
# ...

# %%
df4['TwoWP'] = (df4['TwoW'] / 
                 df2['2022estimates'] * 100)

# %%
df4.head()
# Out:
#     Total  EVSTATIONS  PCINCOME  DieselPrices  Avg.annualhightempcelsius  \
# 0  142260         207     65431         89.71                       33.0
# 1  119822         317    202130         95.59                       34.0
# 2   44950          37     46292         94.04                       31.0
# 3    1958         141    121463         92.76                       32.0
# 4    3938         235     98418         93.93                       32.0
#
#    Avg.annuallowtempcelsius  MaxSubsidyfor2w  Roadtaxexemption2w  \
# 0                      18.0             1000                 100
# 1                      17.0            25000                 100
# 2                      20.0            20000                 100
# 3                      22.0            20000                 100
# 4                      19.0             1000                  99
#
#    Roadtaxexemption4w  Avgunitrate  AirQualityIndex    TwoW  Cluster_Id  \
# ...

# %%
plt.figure(figsize=(10,5))
sns.set_theme(style="whitegrid")
sns.barplot(x='States',y= 'P3', data=df2)
plt.title('Percentage of Three wheeler Population')
plt.ylabel('Percentage')
plt.xlabel('States')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.set_theme(style="whitegrid")
sns.barplot(x='States',y= 'P4', data=df2)
plt.title('Percentage of Four wheeler Population')
plt.ylabel('Percentage')
plt.xlabel('States')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.set_theme(style="whitegrid")
sns.barplot(x='States',y= 'BusP', data=df2)
plt.title('Percentage of Bus Population')
plt.ylabel('Percentage')
plt.xlabel('States')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.set_theme(style="whitegrid")
sns.barplot(x='States',y= 'TotalP', data=df2)
plt.title('Percentage of Total Vehicles Poplulation')
plt.ylabel('Percentage')
plt.xlabel('States')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.set_theme(style="whitegrid")
sns.barplot(x='States',y= 'EVSTATIONSP', data=df2)
plt.title('Percentage of Ev Stations')
plt.ylabel('Percentage')
plt.xlabel('States')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.set_theme(style="whitegrid")
sns.barplot(x='States',y= 'TwoWP', data=df4)
plt.title('Percentage of Two wheeler')
plt.ylabel('Percentage')
plt.xlabel('States')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(17,7))
plt.plot(df4['States'],df4['TwoWP'],label='P2',color="Red")
plt.plot(df2['States'],df2['P3'],label='P3',color='black')
plt.plot(df2['States'],df2['P4'],label='P4',color='blue')
plt.plot(df2['States'],df2['TotalP'],label='TotalP',color='green')
plt.xlabel('States')
plt.ylabel('Percentage')
plt.title('GraphPlot of Two,Three, Four Wheeler population percentage')
plt.xticks(rotation = 90)
plt.legend(loc='upper left')
plt.show()

# %%
df
# Out:
#                            States  2022estimates  2wheeler  3wheeler     4W  \
# 0                    UttarPradesh      233200000     27000    113400      0
# 1                     Maharashtra      125400000    105300      2700  10800
# 2                           Bihar      124900000      5400     39550      0
# 3                      WestBengal       98600000      1958         0      0
# 4                   MadhyaPradesh       85500000      2327       945    608
# 5                       TamilNadu       76600000     62100      5670   5864
# 6                       Rajasthan       80000000      2009       572    335
# 7                       Karnataka       67200000     81000      7830   5400
# 8                         Gujarat       70000000     54000      1350   3353
# 9                   AndhraPradesh       53000000      2171         0    643
# 10                         Odisha       46000000     24300      1350    837
# ...
